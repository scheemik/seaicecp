# %% [markdown]
# # Test the Jupyter Server
#
# The output of the following code blocks can be used to see whether the kernel is running as expected.
#
# ## Select the kernel
#
# First, ensure that the container is running the Jupyter server.
# Then, hit the "Select Kernel" button at the top right of the Jupyter Notebook.
# Next, select "Existing Jupyter Server" and enter the following URL: <http://127.0.0.1:8889/lab>.
# It will ask "Connecting over HTTP without a token may be an insecure connection. Do you want to connect to a possibly insecure server?"
# Select "Yes."
# If you want, you can change the name of the server, but you will need to connect again, so there isn't much point.
# Then, select the kernel.
# Click "Run All" for this notebook and check the outputs of each cell below.
#
# ## Package version
#
# The following block outputs the version of the `seaice_cp` package.
# This tests whether the kernel is aware of the local package.

# %%
import seaicecp 
print(seaicecp.__version__)

# %% [markdown]
# Does the version number match what you expect?
#
# ## Python executable location
#
# The following block shows the file path of the executable being used for Python.
# The file path also reveals where this code is being executed.

# %%
import sys
print(sys.executable)

# %% [markdown]
# This is expected to be `/workspace/.venv/bin/python3`.
# The `/workspace` directory indicates it is running in the container.
# If the output doesn't match, check which kernel is being used.
#
# ## Python version
#
# The following block checks what version of Python is being used in the kernel.

# %%
import sys
print(sys.version)

# %% [markdown]
# This is expected to match the contents of the `.python-version` file, at least for the major and minor version numbers.

# %%
with open('.python-version', 'r') as file:
    print(file.read())
